# %%
import requests

# %% [markdown]
# # Please note that API key is from
# https://www.cityhealthdashboard.com/data-access
#
# Once you sign up and log-in, you can get it.
#
# For ref, Please see:https://cityhealthdashboard.global.ssl.fastly.net/

# %%
#https://api.cityhealthdashboard.com/api/data/city-metric/binge-drinking?token=[api_key]
url = "https://api.cityhealthdashboard.com/api/data/city-metric/binge-drinking?token="
token1 = '4ce08763f76af124d4ee4e80b9ae3eab'

# %%
# We received a ‘200’ code which tells us our request was successful. 

response = requests.get(url+token1)
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'metrics': {'success': True, 'page': 1, 'page_size': 1000, 'records': 1000, 'query_time': 0.039, 'time': 1.852, 'total_records': 2040, 'total_pages': 3}, 'fields': {'state_abbr': 'string', 'state_fips': 'string', 'place_fips': 'string', 'stpl_fips': 'string', 'city_name': 'string', 'metric_name': 'string', 'metric_number': 'number', 'group_name': 'string', 'group_number': 'number', 'num': 'number', 'denom': 'number', 'est': 'number', 'lci': 'number', 'uci': 'number', 'county_indicator': 'number', 'educ_indicator': 'number', 'multiplier_indicator': 'number', 'data_yr_type': 'string', 'geo_level': 'string', 'date_export': 'date'}, 'rows': [{'state_abbr': 'AK', 'state_fips': '02', 'place_fips': '03000', 'stpl_fips': '0203000', 'city_name': 'Anchorage', 'metric_name': 'Binge drinking', 'metric_number': 3, 'group_name': 'total population', 'group_number': 1, 'num': -999, 'denom': -999, 'est': 20.3, 'lci': 20.2, 'uci': 20.4, 'county_indicator': 0, 'educ_indicator': -999, 'multiplier_indic
# ...

# %%
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "fields": {
#         "city_name": "string",
#         "county_indicator": "number",
#         "data_yr_type": "string",
#         "date_export": "date",
#         "denom": "number",
#         "educ_indicator": "number",
#         "est": "number",
#         "geo_level": "string",
#         "group_name": "string",
#         "group_number": "number",
#         "lci": "number",
#         "metric_name": "string",
#         "metric_number": "number",
#         "multiplier_indicator": "number",
#         "num": "number",
#         "place_fips": "string",
#         "state_abbr": "string",
#         "state_fips": "string",
#         "stpl_fips": "string",
#         "uci": "number"
#     },
#     "metrics": {
#         "page": 1,
#         "page_size": 1000,
#         "query_time": 0.039,
#         "records": 1000,
#         "success": true,
#         "time": 1.852,
#         "total_pages": 3,
#         "total_records": 2040
#     },
#     "rows": [
#         {
# ...

# %% [markdown]
# #### Arguments to limit the data by city, state, or year can be called as shown in the following example for New York, NY in 2016:

# %%
ny_2016 = '&city_name=New+York&state_abbr=NY&data_yr_type=2016,+1+Year+Modeled+Estimate'

response1 = requests.get(url+token1+ny_2016)
print(response1.status_code)
# Out:
# 200

# %%
jprint(response1.json())
# Out:
# {
#     "fields": {
#         "city_name": "string",
#         "county_indicator": "number",
#         "data_yr_type": "string",
#         "date_export": "date",
#         "denom": "number",
#         "educ_indicator": "number",
#         "est": "number",
#         "geo_level": "string",
#         "group_name": "string",
#         "group_number": "number",
#         "lci": "number",
#         "metric_name": "string",
#         "metric_number": "number",
#         "multiplier_indicator": "number",
#         "num": "number",
#         "place_fips": "string",
#         "state_abbr": "string",
#         "state_fips": "string",
#         "stpl_fips": "string",
#         "uci": "number"
#     },
#     "metrics": {
#         "page": 1,
#         "page_size": 1000,
#         "query_time": 0.01,
#         "records": 1,
#         "success": true,
#         "time": 3.886,
#         "total_pages": 1,
#         "total_records": 1
#     },
#     "rows": [
#         {
# ...

# %% [markdown]
# ## For multiple year and different metrics, I may use for loop to get this data.
# ## Decision points are which year or year range and what metrics are we need
